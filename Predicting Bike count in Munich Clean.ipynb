# %% [markdown]
# # Predicting Bike count in Munich
#
# To get some pratical experience I chose my own project to practice the concepts introduced in Chapter 9 "Tabular Modelling Deep Dive" of the fastai_v2 course. I wanted to share my approach and would be happy if you could point me to errors, misunderstandings or possible improvements.
#
# 1. [Goal](#introduction)
# 2. [Data](#data)
#     1. [Get data](#getdata)
#     1. [Explore data](#exploredata)
# 3. [Modelling](#model)
#     1. [Random Forest](#rf)
#     2. [Neuronal Net](#nn)
# 4. [Analyze results](#analyze)
# 5. [Improvements](#improve)
# 6. [Conclusion and next steps](#conclusion)

# %% [markdown]
# ## 1. My Goal <a name="introduction"></a>
#
# The city of munich counts the number of bikers on six counting stations throughout munich. They provide those numbers to the public in their open data portal.
#
# Based on this data, can I create a model that predicts the number of bikers for a given day?

# %% [markdown]
# ## 2. The data <a name="data"></a>
#
# At the momente there are 6 permanent bike counting stations in munich. They count bikes with sensors build into the street. The data can be accessed via the open data portal api. e.g. all currently available datasets can be retrieved with this call: https://www.opengov-muenchen.de/api/3/action/package_search?q=Raddauerz%C3%A4hlstellen&rows=1000
#
# In April 2020 the counting station Kreuther changed. The sensor size approximatly doubled in size. Take this into account for data after 1. april.
#
# More information:
#
# * OpenDataPortal Munich Website (german): https://www.opengov-muenchen.de/dataset?tags=Raddauerz%C3%A4hlstellen
# * Info about bike counting stations (Raddauerzählstellen) (german): https://www.opengov-muenchen.de/pages/raddauerzaehlstellen
# * API Doku: https://docs.ckan.org/en/ckan-2.5.3/api/
# * Analysis of data 2017 & 2018 in german - [„Aufs Radl – Fertig? – Los!“ Ergebnisse der Raddauerzählstellen in München 2017 und 2018 (PDF)](https://www.muenchen.de/rathaus/dam/jcr:9a65625e-952f-470f-b6a1-d4270f4526cb/mb190304.pdf)
#
#
# ### 2.1 Get data <a name="getdata"></a>

# %%
import requests
import os
import itertools

# %%
r = requests.get('https://www.opengov-muenchen.de/api/3/action/package_search?q=Raddauerz%C3%A4hlstellen&rows=1000')
json = r.json()

# %%
#json

# %%
def download_csv(url):
    filename = 'data/' + url.rsplit('/',1)[1]
    if os.path.exists(filename):
        print(f'{filename} already exists')
    else:
        r = requests.get(url)
        os.makedirs(os.path.dirname(filename), exist_ok=True)
        with open(filename, 'wb') as f:
            f.write(r.content)
        print(f'{filename} downloaded.')

# %%
resources = [[{'name':res['name'], 'url':res['url']} for res in result['resources'] if res['name'] != 'Raddauerzählstellen in München'] for result in json['result']['results']]
resources = list(itertools.chain.from_iterable(resources))

# %%
for res in resources:
    download_csv(res['url'])
# Out:
# data/rad20170615min.csv already exists
# data/rad201706tage.csv already exists
# data/rad20201015min.csv already exists
# data/rad202010tage.csv already exists
# data/rad20200915min.csv already exists
# data/rad202009tage.csv already exists
# data/rad20200815min.csv already exists
# data/rad202008tage.csv already exists
# data/rad20200715min.csv already exists
# data/rad202007tage.csv already exists
# data/rad20200615min.csv already exists
# data/rad202006tage.csv already exists
# data/rad20200115min.csv already exists
# data/rad202001tage.csv already exists
# data/rad20200315min.csv already exists
# data/rad202003tage.csv already exists
# data/rad20200215min.csv already exists
# data/rad202002tage.csv already exists
# data/rad20190415min.csv already exists
# data/rad201904tage.csv already exists
# data/rad20181115min.csv already exists
# data/rad201811tage.csv already exists
# data/rad20170715min.csv already exists
# data/rad201707tage.csv already exists
# data/rad20170115min.csv already exists
# data/rad201701tage.csv already exists
# data/rad20200415min.csv already exists
# data/rad202004tage.csv already exists
# data/rad20191215min.csv already exists
# data/rad201912tage.csv already exists
# data/rad20191115min.csv already exists
# data/rad201911tage.csv already exists
# data/rad20191015min.csv already exists
# data/rad201910tage.csv already exists
# data/rad20190915min.csv already exists
# data/rad201909tage.csv already exists
# data/rad20190815min.csv already exists
# data/rad201908tage.csv already exists
# data/rad20190715min.csv already exists
# data/rad201907tageneu.csv already exists
# data/rad20190515min.csv already exists
# data/rad201905tage.csv already exists
# data/rad20190315min.csv already exists
# data/rad201903tage.csv already exists
# data/rad20190215min.csv already exists
# data/rad201902tage.csv already exists
# data/rad20190115min.csv already exists
# data/rad201901tage.csv already exists
# data/rad20180315min.csv already exists
# data/rad201803tage.csv already exists
# data/rad20181215min.csv already exists
# data/rad201812tage.csv already exists
# data/rad20180915min.csv already exists
# data/rad201809tage.csv already exists
# data/rad20181015min.csv already exists
# data/rad201810tage.csv already exists
# data/rad20170315min.csv already exists
# data/rad201703tage.csv already exists
# data/rad20170815min.csv already exists
# data/rad201708tage.csv already exists
# data/rad20180715min.csv already exists
# data/rad201807tage.csv already exists
# data/rad20171215min.csv already exists
# data/rad201712tage.csv already exists
# data/rad20171115min.csv already exists
# data/rad201711tage.csv already exists
# data/rad20171015min.csv already exists
# data/rad201710tage.csv already exists
# data/rad20170915min.csv already exists
# data/rad201709tage.csv already exists
# data/rad201702tage.csv already exists
# data/rad20170215min.csv already exists
# data/rad20170415min.csv already exists
# data/rad201704tage.csv already exists
# data/rad20170515min.csv already exists
# data/rad201705tage.csv already exists
# data/rad20180215min.csv already exists
# data/rad201802tage.csv already exists
# data/rad20180115min.csv already exists
# data/rad201801tage.csv already exists
# data/rad20180415min.csv already exists
# data/rad201804tage.csv already exists
# data/rad20180515min.csv already exists
# data/rad201805tage.csv already exists
# data/rad20180615min.csv already exists
# data/rad201806tage.csv already exists
# data/rad20180815min.csv already exists
# data/rad201808tage.csv already exists
# data/rad20200515min.csv already exists
# data/rad202005tage.csv already exists
# data/rad20190615min.csv already exists
# data/rad201906tageneu.csv already exists

# %% [markdown]
# ### 2.2. Explore data

# %%
# pip install pandas

# %%
import pandas as pd

# %%
files = [f for f in os.listdir('data') if os.path.isfile(os.path.join('data', f))]
files.sort()

# %% [markdown]
# #### Data complete?
# For each month there should be two csv files (15 min und day). Therefore there should 92 files `(3 years * 12 month + 10 (10 for october)) * 2`

# %%
len(files) == (3 * 12 + 10) * 2
# Out:
# True

# %% [markdown]
# #### How does the data look like?

# %%
df_min15 = pd.read_csv('data/rad20201015min.csv')
df_min15
# Out:
#             datum uhrzeit_start uhrzeit_ende zaehlstelle  richtung_1  \
# 0      2020.10.01         00:00        00:15      Arnulf           2
# 1      2020.10.01         00:15        00:30      Arnulf           1
# 2      2020.10.01         00:30        00:45      Arnulf           0
# 3      2020.10.01         00:45        01:00      Arnulf           0
# 4      2020.10.01         01:00        01:15      Arnulf           1
# ...           ...           ...          ...         ...         ...
# 17851  2020.10.31         22:45        23:00     Erhardt           5
# 17852  2020.10.31         23:00        23:15     Erhardt           8
# 17853  2020.10.31         23:15        23:30     Erhardt           5
# 17854  2020.10.31         23:30        23:45     Erhardt           5
# 17855  2020.10.31         23:45        00:00     Erhardt           5
#
#        richtung_2  gesamt
# 0               0       2
# 1               0       1
# 2               0       0
# 3               0       0
# 4               0       1
# ...           ...     ...
# 17851          14      19
# 17852          11      19
# 17853           9      14
# 17854           9      14
# 17855           8      13
#
# [17856 rows x 7 columns]

# %%
df_day = pd.read_csv('data/rad202010tage.csv')
df_day
# Out:
#           datum uhrzeit_start  uhrzeit_ende zaehlstelle  richtung_1  \
# 0    2020.10.01         00:00         23.59      Arnulf        1738
# 1    2020.10.02         00:00         23.59      Arnulf        1469
# 2    2020.10.03         00:00         23.59      Arnulf         548
# 3    2020.10.04         00:00         23.59      Arnulf         821
# 4    2020.10.05         00:00         23.59      Arnulf        1048
# ..          ...           ...           ...         ...         ...
# 181  2020.10.27         00:00         23.59     Erhardt        2289
# 182  2020.10.28         00:00         23.59     Erhardt        2675
# 183  2020.10.29         00:00         23.59     Erhardt        1334
# 184  2020.10.30         00:00         23.59     Erhardt        2167
# 185  2020.10.31         00:00         23.59     Erhardt        2780
#
#      richtung_2  gesamt  min-temp  max-temp  niederschlag  bewoelkung  \
# 0           107    1845       6.5      19.4           0.0          65
# 1            89    1558       9.8      18.4           0.0          99
# 2            37     585       5.1      22.1           2.9          75
# 3            37     858       4.7      17.3           0.7          73
# 4            63    1111       9.0      14.6           4.7          98
# ..          ...     ...       ...       ...           ...         ...
# 181        2213    4502       3.9      11.1           0.0          75
# 182        2592    5267       3.5      14.7           2.4          95
# 183        1342    2676       8.9      11.2          15.5          94
# 184        2142    4309       9.0      14.7           0.0          99
# 185        2621    5401       6.3      17.9           0.0          55
#
#      sonnenstunden
# 0              8.2
# 1              0.9
# 2              2.9
# 3              6.5
# 4              1.8
# ..             ...
# 181            1.5
# 182            1.3
# 183            0.0
# 184            0.6
# 185            8.9
#
# [186 rows x 12 columns]

# %% [markdown]
# * Every file contains all counting_stations (zaehlstelle).
# * The counts are in three columns: direction_1 (richtung_1), direction_2 (richtung_2) and total (gesamt)
# * The day datasets also contain weather information - min/max temp, sun hours, rain and cloud

# %%
# Available counting stations (zaehlstellen):
df_day.zaehlstelle.unique()
# Out:
# array(['Arnulf', 'Kreuther', 'Olympia', 'Hirsch', 'Margareten', 'Erhardt'],
#       dtype=object)

# %%
# getDataframe of datafiles
# - prefixes - filter used files by prefix e.g. rad2018 for year 2018
# - zaehlstelle - filter by given counting station ()
def getDataframe(prefixes, zaehlstelle: str):
    files = [f for f in os.listdir('data') if os.path.isfile(os.path.join('data', f)) and f.endswith('tage.csv')]
    files = [f for f in files if f.startswith(prefixes)]
    df = pd.concat([pd.read_csv(os.path.join('data', f)) for f in files])
    return df[df.zaehlstelle == zaehlstelle].sort_values(by=['datum'])

# %%
df_arnulf = getDataframe(zaehlstelle='Arnulf', prefixes = ('rad2017', 'rad2018', 'rad2019'))

# %%
df_arnulf
# Out:
#          datum uhrzeit_start uhrzeit_ende zaehlstelle  richtung_1  richtung_2  \
# 0   2017.01.01      00:00:00        23.59      Arnulf         121          14
# 1   2017.01.02      00:00:00        23.59      Arnulf         362          38
# 2   2017.01.03      00:00:00        23.59      Arnulf         232          30
# 3   2017.01.04      00:00:00        23.59      Arnulf         182          25
# 4   2017.01.05      00:00:00        23.59      Arnulf         193          31
# ..         ...           ...          ...         ...         ...         ...
# 26  2019.12.27         00:00        23.59      Arnulf         312          30
# 27  2019.12.28         00:00        23.59      Arnulf         337          37
# 28  2019.12.29         00:00        23.59      Arnulf         253          32
# 29  2019.12.30         00:00        23.59      Arnulf         550          52
# 30  2019.12.31         00:00        23.59      Arnulf         329          34
#
#     gesamt  min-temp  max-temp  niederschlag  bewoelkung  sonnenstunden
# 0      135      -6.1       2.6           0.0          36            5.9
# 1      400      -5.4       0.8           3.2          69            0.3
# 2      262      -2.1       0.6           0.0          85            3.6
# 3      207      -0.9       1.3           2.2          94            0.0
# 4      224      -7.1      -0.2           0.0          88            0.0
# ..     ...       ...       ...           ...         ...            ...
# 26     342       1.7       4.9           4.9          98            0.0
# 27     374      -2.1       2.0           0.0          69            3.2
# 28     285      -4.8       2.5           0.0          26            7.9
# 29     602      -4.4       6.0           0.0           9            8.0
# 30     363      -0.5       8.6           0.0          60            6.8
#
# [1034 rows x 12 columns]

# %% [markdown]
# #### Are there missing days?

# %%
from datetime import date, timedelta, datetime

def findMissingDays(df):
    dates = df.datum.map(lambda x: datetime.strptime(x, '%Y.%m.%d')).tolist()
    dates.sort()
    d = set(dates[0] + timedelta(x) for x in range((dates[-1] - dates[0]).days))
    return sorted(d - set(dates))

# %%
missing = findMissingDays(df_arnulf)
len(missing), missing[0], missing[-1]
# Out:
# (61, Timestamp('2019-06-01 00:00:00'), Timestamp('2019-07-31 00:00:00'))

# %% [markdown]
# There are missing days from June to July 2019

# %% [markdown]
# #### Plot counts for a month

# %%
# pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams['figure.figsize'] = [20, 15]

df = getDataframe(prefixes=('rad2018'), zaehlstelle='Arnulf')

# %%
df.plot.bar(x='datum', y='gesamt', rot=45)
ax1 = plt.axes()
x_axis = ax1.axes.get_xaxis()
for index, label in enumerate(x_axis.get_ticklabels()):
    if not label.get_text().endswith('01'):
        label.set_visible(False)
plt.show()
plt.close()
# Out:
# <ipython-input-23-f5cfea7d9034>:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax1 = plt.axes()

# %% [markdown]
# ## 3. Modelling <a name="model"></a>
#
# I will work with the daily numbers because they already contain the weather information.
# I will use the year 2017 & 2018 as training data and 2019 for validation.

# %% [markdown]
# ### 3.1. Random Forest <a name="rf"></a>

# %% [markdown]
# #### Prepare data

# %%
# conda install -c fastai -c pytorch fastai

# %%
from fastai.tabular.all import *
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729096996/work/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
df = getDataframe(prefixes=('rad2017', 'rad2018', 'rad2019'), zaehlstelle='Arnulf')
# add date columns like day of week etc. 
df = add_datepart(df, 'datum')
df.head()
# Out:
#   uhrzeit_start uhrzeit_ende  datumWeek zaehlstelle  richtung_1  richtung_2  \
# 0      00:00:00        23.59         52      Arnulf         121          14
# 1      00:00:00        23.59          1      Arnulf         362          38
# 2      00:00:00        23.59          1      Arnulf         232          30
# 3      00:00:00        23.59          1      Arnulf         182          25
# 4      00:00:00        23.59          1      Arnulf         193          31
#
#    gesamt  min-temp  max-temp  niederschlag  ...  datumDay  datumDayofweek  \
# 0     135      -6.1       2.6           0.0  ...         1               6
# 1     400      -5.4       0.8           3.2  ...         2               0
# 2     262      -2.1       0.6           0.0  ...         3               1
# 3     207      -0.9       1.3           2.2  ...         4               2
# 4     224      -7.1      -0.2           0.0  ...         5               3
#
#    datumDayofyear  datumIs_month_end  datumIs_month_start  \
# 0               1              False                 True
# 1               2              False                False
# 2               3              False                False
# 3               4              False                False
# 4               5              False                False
#
#    datumIs_quarter_end  datumIs_quarter_start  datumIs_year_end  \
# 0                False                   True             False
# 1                False                  False             False
# 2                False                  False             False
# 3                False                  False             False
# 4                False                  False             False
#
#    datumIs_year_start  datumElapsed
# 0                True    1483228800
# 1               False    1483315200
# 2               False    1483401600
# 3               False    1483488000
# 4               False    1483574400
#
# [5 rows x 24 columns]

# %%
# drop richtung columns because they sum up to gesamt value, which we want to predict
df = df.drop(['richtung_1', 'richtung_2'], axis=1)

# %%
# Create Tabular Pandas
procs = [Categorify, FillMissing] # processings or transformations
cond = (df.datumYear<2019)
train_idx = np.where(cond)[0]
valid_idx = np.where(~cond)[0]

splits = (list(train_idx),list(valid_idx))

dep_var = 'gesamt' # dependent variable, the number we want to predict

cont, cat = cont_cat_split(df, 1, dep_var=dep_var)
to = TabularPandas(df, procs, cat, cont, y_names=dep_var, splits=splits)

# %%
to.show(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uhrzeit_start</th>
#       <th>uhrzeit_ende</th>
#       <th>datumWeek</th>
#       <th>zaehlstelle</th>
#       <th>datumIs_month_end</th>
#       <th>datumIs_month_start</th>
#       <th>datumIs_quarter_end</th>
#       <th>datumIs_quarter_start</th>
#       <th>datumIs_year_end</th>
#       <th>datumIs_year_start</th>
#       <th>datumElapsed</th>
#       <th>min-temp</th>
#       <th>max-temp</th>
#       <th>niederschlag</th>
#       <th>bewoelkung</th>
#       <th>sonnenstunden</th>
#       <th>datumYear</th>
#       <th>datumMonth</th>
#       <th>datumDay</th>
#       <th>datumDayofweek</th>
#       <th>datumDayofyear</th>
#       <th>gesamt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>00:00:00</td>
#       <td>23.59</td>
#       <td>52</td>
#       <td>Arnulf</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1483228800</td>
#       <td>-6.1</td>
#       <td>2.6</td>
#       <td>0.0</td>
#       <td>36</td>
#       <td>5.9</td>
#       <td>2017</td>
#       <td>1</td>
#       <td>1</td>
#       <td>6</td>
#       <td>1</td>
#       <td>135</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>00:00:00</td>
#       <td>23.59</td>
#       <td>1</td>
#       <td>Arnulf</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>1483315200</td>
#       <td>-5.4</td>
#       <td>0.8</td>
#       <td>3.2</td>
#       <td>69</td>
#       <td>0.3</td>
#       <td>2017</td>
#       <td>1</td>
#       <td>2</td>
#       <td>0</td>
#       <td>2</td>
#       <td>400</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>00:00:00</td>
#       <td>23.59</td>
#       <td>1</td>
#       <td>Arnulf</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>1483401600</td>
#       <td>-2.1</td>
#       <td>0.6</td>
#       <td>0.0</td>
#       <td>85</td>
#       <td>3.6</td>
#       <td>2017</td>
#       <td>1</td>
#       <td>3</td>
#       <td>1</td>
#       <td>3</td>
#       <td>262</td>
#     </tr>
#   </tbody>
# </table>

# %%
# save
save_pickle((URLs.path()/'../to.pkl'), to)

# %% [markdown]
# #### Train Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
xs,y = to.train.xs, to.train.y
valid_xs, valid_y = to.valid.xs, to.valid.y

# %%
def rf(xs, y, n_estimators=40, max_features=0.5, min_samples_leaf=5, **kwargs):
    return RandomForestRegressor(n_jobs=-1, n_estimators=n_estimators, min_samples_leaf=min_samples_leaf, max_features=max_features, oob_score=True).fit(xs,y)

# %%
# root mean square error - penalizes large differences. Would MAE be better as metric?
def r_mse(pred,y): return round(math.sqrt(((pred-y)**2).mean()), 6)
def m_rmse(m, xs, y): return r_mse(m.predict(xs), y)

# %%
m = rf(xs, y)

# %%
m_rmse(m, xs, y), m_rmse(m, valid_xs, valid_y)
# Out:
# (153.996995, 288.783409)

# %%
mean_absolute_error(m.predict(xs), y),mean_absolute_error(m.predict(valid_xs), valid_y)
# Out:
# (108.49849619051132, 218.31408270044335)

# %%
preds = np.stack([t.predict(valid_xs) for t in m.estimators_])
r_mse(preds.mean(0), valid_y)
# Out:
# 288.783409

# %%
plt.plot([r_mse(preds[:i+1].mean(0), valid_y) for i in range(40)]);

# %% [markdown]
# 😳 Question: Best result in a previous run seem to be arround 20 not 40 what does that mean?

# %% [markdown]
# #### Out of bag error
# Good metric to check why our predictions in our training set or better then in our validation set. 108.36805410446944 vs 212.6982400192359

# %%
r_mse(m.oob_prediction_, y)
# Out:
# 217.372348

# %% [markdown]
# 😳 Our error in the training set is higher than in the validation set. The example in the fastai book p.302 has an example where the error is lower.
#
# What does this indicate?

# %% [markdown]
# #### Prediction confidence
#
# how confident can I be in those predictions? One way is to look at the variance between the trees in the forest. Smaller is better.

# %%
preds = np.stack([t.predict(valid_xs) for t in m.estimators_])
print(preds.shape) # 40 trees, with 304 predictions for each day
preds_std = preds.std(0) # standard deviation
preds_std[:20]
# Out:
# (40, 304)
# array([225.54490439, 241.09744157, 203.33691232, 157.01424121,
#        117.44318591, 110.92082474, 213.53150583, 153.41316659,
#        155.06138105, 152.75744748, 161.25670466,  80.51888476,
#         77.78013165, 116.59262411, 218.21188152, 271.57741662,
#        228.63414535, 220.76762367, 160.51263966, 145.7269276 ])

# %% [markdown]
# #### Feature importance
#
# Which feature are most important?

# %%
def rf_feat_importance(m, df):
    return pd.DataFrame({'cols':df.columns, 'imp':m.feature_importances_}).sort_values('imp', ascending=False)
fi = rf_feat_importance(m, xs)
fi[:10]
# Out:
#               cols       imp
# 12        max-temp  0.375240
# 19  datumDayofweek  0.201645
# 15   sonnenstunden  0.150270
# 11        min-temp  0.121440
# 20  datumDayofyear  0.045371
# 13    niederschlag  0.026512
# 14      bewoelkung  0.025478
# 2        datumWeek  0.021068
# 10    datumElapsed  0.014599
# 18        datumDay  0.008647

# %% [markdown]
# Most important features are max-temp followed by day of week. Seems reasonable to me. e.g. workdays vs weekend and cold days vs warm days.

# %%
def plot_fi(fi):
    return fi.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)
plot_fi(fi[:20]);

# %% [markdown]
# #### Remove unimportant features

# %%
to_keep =fi[fi.imp > 0.005].cols
len(to_keep)
# Out:
# 11

# %%
xs_imp = xs[to_keep]
valid_xs_imp = valid_xs[to_keep]

# %%
m = rf(xs_imp, y)
m_rmse(m, xs_imp, y), m_rmse(m, valid_xs_imp, valid_y)
# Out:
# (155.541385, 293.994562)

# %% [markdown]
# 😳 Got worse in comparison to prev run: 151.42499, 285.167373. But the removed columns shouldn't be important e.g. uhrzeit_start/end is always the same.

# %% [markdown]
# #### Redundant features

# %%
from scipy.cluster import hierarchy as hc

def cluster_columns(df, figsize=(10,6), font_size=12):
    corr = np.round(scipy.stats.spearmanr(df).correlation, 4)
    corr_condensed = hc.distance.squareform(1-corr)
    z = hc.linkage(corr_condensed, method='average')
    fig = plt.figure(figsize=figsize)
    hc.dendrogram(z, labels=df.columns, orientation='left', leaf_font_size=font_size)
    plt.show()
    
cluster_columns(xs_imp)

# %%
xs_imp.head()
# Out:
#    max-temp  datumDayofweek  sonnenstunden  min-temp  datumDayofyear  \
# 0       2.6               6            5.9      -6.1               1
# 1       0.8               0            0.3      -5.4               2
# 2       0.6               1            3.6      -2.1               3
# 3       1.3               2            0.0      -0.9               4
# 4      -0.2               3            0.0      -7.1               5
#
#    niederschlag  bewoelkung  datumWeek  datumElapsed  datumDay  datumMonth
# 0           0.0          36         52             1         1           1
# 1           3.2          69          1             2         2           1
# 2           0.0          85          1             3         3           1
# 3           2.2          94          1             4         4           1
# 4           0.0          88          1             5         5           1

# %% [markdown]
# month and day of year are close, makes sense both indicate the "season" or the progress into the year.
# Will keep it for now.

# %% [markdown]
# #### Waterfall Chart

# %%
#!pip install treeinterpreter
#!pip install waterfallcharts

# %%
from treeinterpreter import treeinterpreter
row = valid_xs_imp.iloc[:1]
prediction,bias,contributions = treeinterpreter.predict(m, row.values)
prediction[0], bias[0], contributions[0].sum()
# Out:
# /opt/conda/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# (array([685.65983929]), 1167.7376369863014, -482.07779769364964)

# %%
import waterfall_chart
waterfall_chart.plot(valid_xs_imp.columns, contributions[0], threshold=0.08, rotation_value=45)
# Out:
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# Indicates the importance of different features for the prediction.

# %% [markdown]
# #### Out of domain data

# %%
df_dom = pd.concat([xs_imp, valid_xs_imp])
is_valid = np.array([0]*len(xs_imp) + [1]*len(valid_xs_imp))

# %%
# RandomForest to decide if value is in train oder valid set.
m = rf(df_dom, is_valid)
rf_feat_importance(m, df_dom)[:6]
# Out:
#               cols       imp
# 8     datumElapsed  0.967610
# 0         max-temp  0.009533
# 3         min-temp  0.007161
# 4   datumDayofyear  0.005022
# 6       bewoelkung  0.004718
# 10      datumMonth  0.003053

# %% [markdown]
# By extracting the most important features which seperate train from validation set we find feature which we could drop.

# %%
xs_final = xs_imp.drop('datumElapsed', axis=1)
valid_xs_final = valid_xs_imp.drop('datumElapsed', axis=1)
m = rf(xs_final, y)
print(f'without out of dom: {m_rmse(m, valid_xs_final, valid_y)}')
# Out:
# without out of dom: 285.617843

# %% [markdown]
# 😳 Got worse again.

# %% [markdown]
# ### Summary of RandomForest

# %%
m = rf(xs, y)
print(f'orig: {m_rmse(m, valid_xs, valid_y)}')
m = rf(xs_imp, y)
print(f'imp: {m_rmse(m, valid_xs_imp, valid_y)}')
m = rf(xs_imp.drop('datumElapsed',axis=1), y)
print(f'without out of dom: {m_rmse(m, valid_xs_imp.drop("datumElapsed",axis=1), valid_y)}')
# Out:
# orig: 289.000991
# imp: 283.293512
# without out of dom: 285.91608

# %% [markdown]
# #### less trees

# %%
m = rf(xs, y, 25)
print(f'orig: {m_rmse(m, valid_xs, valid_y)}')
m = rf(xs_imp, y, 25)
print(f'imp: {m_rmse(m, valid_xs_imp, valid_y)}')
m = rf(xs_imp.drop('datumElapsed',axis=1), y, 25)
print(f'without out of dom: {m_rmse(m, valid_xs_imp.drop("datumElapsed",axis=1), valid_y)}')
# Out:
# orig: 295.129337
# imp: 287.459466
# without out of dom: 284.393441

# %% [markdown]
# #### Open questions

# %% [markdown]
# 😳 Results change on every rerun. Therfore: How comparable are the results with the different changes then?
#
# Should I fix a seed for the RandomForest, is this possible?

# %% [markdown]
# ### 3.1. Neural Net <a name="nn"></a>
#
# Let's try it with a neural net

# %%
df_nn = getDataframe(zaehlstelle='Arnulf', prefixes = ('rad2017', 'rad2018', 'rad2019'))
df_nn = add_datepart(df_nn, 'datum')
df_nn = df_nn[list(xs_final.columns) + [dep_var]]
df_nn
# Out:
#     max-temp  datumDayofweek  sonnenstunden  min-temp  datumDayofyear  \
# 0        2.6               6            5.9      -6.1               1
# 1        0.8               0            0.3      -5.4               2
# 2        0.6               1            3.6      -2.1               3
# 3        1.3               2            0.0      -0.9               4
# 4       -0.2               3            0.0      -7.1               5
# ..       ...             ...            ...       ...             ...
# 26       4.9               4            0.0       1.7             361
# 27       2.0               5            3.2      -2.1             362
# 28       2.5               6            7.9      -4.8             363
# 29       6.0               0            8.0      -4.4             364
# 30       8.6               1            6.8      -0.5             365
#
#     niederschlag  bewoelkung  datumWeek  datumDay  datumMonth  gesamt
# 0            0.0          36         52         1           1     135
# 1            3.2          69          1         2           1     400
# 2            0.0          85          1         3           1     262
# 3            2.2          94          1         4           1     207
# 4            0.0          88          1         5           1     224
# ..           ...         ...        ...       ...         ...     ...
# 26           4.9          98         52        27          12     342
# 27           0.0          69         52        28          12     374
# 28           0.0          26         52        29          12     285
# 29           0.0           9          1        30          12     602
# 30           0.0          60          1        31          12     363
#
# [1034 rows x 11 columns]

# %%
cont_nn, cat_nn = cont_cat_split(df_nn, max_card=9000, dep_var=dep_var)

# %%
cont_nn, cat_nn
# Out:
# (['max-temp', 'sonnenstunden', 'min-temp', 'niederschlag'],
#  ['datumDayofweek',
#   'datumDayofyear',
#   'bewoelkung',
#   'datumWeek',
#   'datumDay',
#   'datumMonth'])

# %%
df_nn[cat_nn].nunique()
# Out:
# datumDayofweek      7
# datumDayofyear    365
# bewoelkung         81
# datumWeek          52
# datumDay           31
# datumMonth         12
# dtype: int64

# %%
df_nn=df_nn.astype('float')

procs_nn = [Categorify, FillMissing, Normalize]
to_nn = TabularPandas(df_nn, procs_nn, cat_nn, cont_nn, splits=splits, y_names=dep_var)

# %%
dls = to_nn.dataloaders()

# %%
learn = tabular_learner(dls, y_range=(29,2707), layers=[500,250], n_out=1, loss_func=F.mse_loss)

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.005754399299621582, lr_steep=0.0006918309954926372)

# %%
learn.fit_one_cycle(20, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>299046.781250</td>
#       <td>247648.203125</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>193584.703125</td>
#       <td>179065.078125</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>156744.328125</td>
#       <td>181483.187500</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>129202.851562</td>
#       <td>137900.703125</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>113962.117188</td>
#       <td>99555.101562</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>101935.632812</td>
#       <td>145445.546875</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>89923.929688</td>
#       <td>92406.601562</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>78806.632812</td>
#       <td>89124.750000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>66486.953125</td>
#       <td>80846.953125</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>55665.832031</td>
#       <td>82235.523438</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>46425.562500</td>
#       <td>78509.554688</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>39739.445312</td>
#       <td>76142.281250</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>33468.933594</td>
#       <td>81403.656250</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>29011.386719</td>
#       <td>75390.734375</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>25259.339844</td>
#       <td>76732.710938</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>21629.035156</td>
#       <td>75867.093750</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>18416.199219</td>
#       <td>75704.890625</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>15682.397461</td>
#       <td>75938.062500</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>13389.255859</td>
#       <td>75841.937500</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>11625.359375</td>
#       <td>76150.226562</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds,targs = learn.get_preds()
r_mse(preds,targs)
# Out:
# 275.953305

# %% [markdown]
# Is better than the random forest

# %% [markdown]
# ## 4. Analyizing results <a name="analyze"></a>

# %% [markdown]
# ### 4.1 Other metrics for evaluation?
#
# Above I used the root mean square error to get a metric for the models. It is helpful to compare both models with each other. Are there other metrics that would help me to get a better understanding of the performance of the models?

# %%
# results
rf_m = rf(xs_final, y)

rf_preds = rf_m.predict(valid_xs_final)
nn_preds, nn_y = learn.get_preds()

# %%
from fastai import metrics

# %% [markdown]
# #### Root Mean Squared Error (RMSE)

# %%
# Root Mean Squared Error (RMSE)
print(r_mse(rf_preds, valid_y))
print(r_mse(nn_preds, nn_y))
# Out:
# 287.257822
# 275.953305

# %% [markdown]
# Penalizes bigger errors more than MAE.

# %% [markdown]
# #### Mean absolute error (MAE)

# %%
# Mean absolute error (MAE)
def mae(preds, y): return np.abs(preds - y).mean()

print(mae(rf_preds, valid_y))
print(mae(nn_preds, nn_y).numpy())
# Out:
# 220.31331891407953
# 202.39781

# %% [markdown]
# Allows a more intuitive understanding, as the error says, it is the mean absolute error. But could we set it in relation to range of values to get a better understanding?

# %% [markdown]
# #### Mean absolute percentage error (MAPE)

# %%
# Mean absolute percentage error (MAPE)
def mape(preds, y): return np.abs((preds - y)/preds).mean()

print(mape(rf_preds, valid_y))
print(mape(nn_preds, nn_y).numpy())
# Out:
# 0.2453578660428034
# 0.234537

# %% [markdown]
# Ok so we are arround 23% off. Seems pretty high to me but maybe it is still useful for traffic planer?

# %% [markdown]
# #### normalized Mean Absolute Error / nMAE

# %%
def nmae(preds, y): return np.abs((preds - y)).mean() / np.abs(preds).mean()

print(nmae(rf_preds, valid_y))
print(nmae(nn_preds, nn_y).numpy())
# Out:
# 0.2143810523421813
# 0.19272237

# %% [markdown]
# Another relative metric. Seems to also be used quite frequently, but I'm not sure what the disadvantages or advantages between MAPE and nMAE are. Some also seam to switch up the definition of both.

# %% [markdown]
# ### 4.2 Visualize results
#
# Could I get more insights by visualizing the data and results?

# %% [markdown]
# ### Plot the results

# %%
# plot a bar chart
plt.bar(valid_xs['datumDayofyear'], rf_preds, label='RandomForest')
plt.bar(valid_xs['datumDayofyear'], nn_preds, label='Neuronal Net')
plt.bar(valid_xs['datumDayofyear'], valid_y, label='Real data')
plt.xlabel('day')
plt.ylabel('total')
plt.title("Arnulf")
plt.legend();

# %% [markdown]
# Looks quite chaotic because it is too much data and small values are hidden behind the other bars. I played arround with a few different visualization but I think the cleanest one is following:

# %%
df = getDataframe(prefixes=('rad2019'), zaehlstelle='Arnulf')

# %%
def addMissingDays(df):
    df['date'] = pd.to_datetime(df['datum'], format="%Y.%m.%d")
    idx = pd.date_range(df['date'].iloc[0], df['date'].iloc[-1])
    df.index = pd.DatetimeIndex(df['date'])
    df = df.reindex(idx)
    return df

# %%
df = addMissingDays(df)

# %%
def getPredsForRF(df):
    df = add_datepart(df, 'datum')
    results = pd.DataFrame(columns=['date', 'pred'])
    for index, x in df.iterrows():
        pred = -1
        if not pd.isnull(x['gesamt']):
            pred = rf_m.predict([x[list(xs_final.columns)]])[0]     
        dfTemp = pd.DataFrame(data={'date': [x['date']], 'pred': [pred]})
        results = results.append(dfTemp)
    return results

# %%
rf_2019 = getPredsForRF(pred_df)

# %%
def plotResults(df, preds, s=0, n=365, title='Arnulf', label_df='2019', label_pred='RandomForest'):
    plt.bar(preds['date'][s:n], preds['pred'][s:n], label=label_pred, color='blue', width=0.8)
    plt.bar(df['date'][s:n], df['gesamt'][s:n], label=label_df, color='red', width=0.4)
    plt.xlabel('day')
    plt.ylabel('total')
    plt.title(title)
    plt.legend()

# %%
plotResults(df, rf_2019, n=50)

# %% [markdown]
# By stepping through different timeframes I can see big errors. But to be true I didn't identify anything useful. Maybe there is a better visualisation out there?

# %% [markdown]
# ### 4.3 When do the biggest errors happen?
#
# I would like to know what the reasons are for the errors. So I think it is a good idea to look at the biggest errors.

# %%
def getPredsForRF(df):
    df = add_datepart(df, 'datum')
    results = pd.DataFrame(columns=['date', 'pred'])
    for index, x in df.iterrows():
        pred = -1
        d = x['date']
        if not pd.isnull(x['gesamt']):
            pred = rf_m.predict([x[list(xs_final.columns)]])[0]
        dfTemp = pd.DataFrame(data={'date': index, 'pred': [pred]})
        results = results.append(dfTemp)
    return results

# %%
df2019 = getDataframe(prefixes=('rad2019'), zaehlstelle='Arnulf')
df2019 = addMissingDays(df2019)
preds2019RF = getPredsForRF(df2019)

# %%
errors = df2019['gesamt'].replace(np.NaN, -1).subtract(preds2019RF.set_index(preds2019RF.date)['pred'])

# %%
# top errors for random forest
errors.sort_values(ascending=False, key=lambda x: np.abs(x))[:20]
# Out:
# 2019-04-19   -1169.309397
# 2019-05-30   -1091.038575
# 2019-04-22   -1060.019251
# 2019-05-31    -903.489810
# 2019-05-24    -767.264364
# 2019-08-15    -761.757006
# 2019-05-01    -753.734933
# 2019-10-22     693.923888
# 2019-12-05     651.629489
# 2019-05-27    -626.950248
# 2019-09-20     605.425496
# 2019-05-23    -604.508012
# 2019-05-26    -586.506392
# 2019-10-03    -585.411819
# 2019-05-25    -569.976292
# 2019-12-11     538.910820
# 2019-04-21    -527.330637
# 2019-11-07     525.768915
# 2019-10-01     516.171127
# 2019-09-26     507.204053
# dtype: float64

# %% [markdown]
# * 8 of 20 biggest erros happen on a national holiday (feiertag)
# * 1 is durent a school holidays
# * 1 is a "Brückentag"
#
# So this looks like a promising way to improve my dataset by adding national holidays, school holidays to the dataset. In the future it might also be helpful to add "Brückentage" or days before a long weekend.
#
#
# ```
# 2019-04-19   -1180.442298 Karfreitag
# 2019-05-30   -1179.176310 Christi Himmelfahrt
# 2019-04-22   -1059.768092 Ostermontag
# 2019-05-31    -954.947565 Brückentag Christi Himmelfahrt
# 2019-08-15    -772.263989 Maria Himmelfahrt
# 2019-05-24    -744.230733 ?
# 2019-10-22     696.795180 ?
# 2019-05-01    -695.081500 Schulferien Weihnachten
# 2019-12-05     674.750098 ?
# 2019-09-20     633.990541 ?
# 2019-05-23    -630.930030 ?
# 2019-05-26    -607.316037 ?
# 2019-10-03    -597.941322 Tag der deutschen Einheit
# 2019-11-01    -585.093491 Allerheiligen
# 2019-04-21    -565.883708 ?
# 2019-05-27    -565.291106 ?
# 2019-05-25    -544.784515 ?
# 2019-05-29    -538.861066 Mittwoch vor Feiertag
# 2019-09-27     537.904750 ?
# 2019-09-06     524.922845 Schulferien Sommer
# ```

# %% [markdown]
# ## 5. Improvements <a name="improve"></a>

# %% [markdown]
# ### 5.1 Add more features to dataset

# %% [markdown]
# #### National holidays / Feiertage

# %% [markdown]
# For national holidays there exists an API https://feiertage-api.de/

# %%
def getFeiertage(jahre = [2017,2018,2019], bundesland = 'BY', ignore = ['Augsburger Friedensfest']):
    feiertage_df = pd.DataFrame(columns={'date','name'})
    for jahr in jahre:
        r = requests.get(f'https://feiertage-api.de/api/?jahr={jahr}&nur_land={bundesland}')
        json = r.json()
        for key, d in json.items():
            if not key in ignore:
                feiertage_df = feiertage_df.append({'date': datetime.strptime(d['datum'], "%Y-%m-%d"), 'name':key}, ignore_index=True)
    return feiertage_df

# %%
getFeiertage()[:10]
# Out:
#                         name       date
# 0                Neujahrstag 2017-01-01
# 1        Heilige Drei Könige 2017-01-06
# 2                 Karfreitag 2017-04-14
# 3                Ostermontag 2017-04-17
# 4             Tag der Arbeit 2017-05-01
# 5        Christi Himmelfahrt 2017-05-25
# 6              Pfingstmontag 2017-06-05
# 7               Fronleichnam 2017-06-15
# 8          Mariä Himmelfahrt 2017-08-15
# 9  Tag der Deutschen Einheit 2017-10-03

# %% [markdown]
# #### School holidays / Schulferien

# %% [markdown]
# Also for this an open API exists: https://ferien-api.de/

# %%
def getFerientage(jahre = [2017,2018,2019], bundesland = 'BY'):
    ferientage_df = pd.DataFrame(columns={'date', 'name'})
    for jahr in jahre:
        r = requests.get(f'https://ferien-api.de/api/v1/holidays/{bundesland}/{jahr}')
        json = r.json()

        for f in json:
            start = datetime.strptime(f['start'], '%Y-%m-%dT%H:%MZ')
            end = datetime.strptime(f['end'], '%Y-%m-%dT%H:%MZ')
            dates = pd.date_range(start, end)

            df = pd.DataFrame({'date': dates, 'name':f['name']})

            ferientage_df = ferientage_df.append(df)
    return ferientage_df

# %%
getFerientage()[:10]
# Out:
#            name       date
# 0  winterferien 2017-02-27
# 1  winterferien 2017-02-28
# 2  winterferien 2017-03-01
# 3  winterferien 2017-03-02
# 4  winterferien 2017-03-03
# 5  winterferien 2017-03-04
# 0   osterferien 2017-04-10
# 1   osterferien 2017-04-11
# 2   osterferien 2017-04-12
# 3   osterferien 2017-04-13

# %% [markdown]
# ### Add as additional columns

# %%
feiertage_df = getFeiertage()
ferientage_df = getFerientage()

# %%
def add_date_feature(df, name, dates):
    df[name] = False
    df.loc[df['date'].isin(dates), name] = True

# %%
df = getDataframe(prefixes=('rad2019'), zaehlstelle='Arnulf')
df['date'] = pd.to_datetime(df['datum'], format="%Y.%m.%d")
df = add_datepart(df, 'datum')
add_date_feature(df, 'feiertag', feiertage_df['date'])
add_date_feature(df, 'ferientag', ferientage_df['date'])
df[:1]
# Out:
#   uhrzeit_start  uhrzeit_ende  datumWeek zaehlstelle  richtung_1  richtung_2  \
# 0      00:00:00         23.59          1      Arnulf         138          14
#
#    gesamt  min-temp  max-temp  niederschlag  ...  datumDayofyear  \
# 0     152       2.7       5.2           1.6  ...               1
#
#    datumIs_month_end datumIs_month_start  datumIs_quarter_end  \
# 0              False                True                False
#
#    datumIs_quarter_start  datumIs_year_end  datumIs_year_start  datumElapsed  \
# 0                   True             False                True    1546300800
#
#    feiertag  ferientag
# 0      True       True
#
# [1 rows x 27 columns]

# %% [markdown]
# ### 5.2 RandomForest with new data

# %%
dep_var = 'gesamt' # dependent variable, the number we want to predict
usedColumns = np.append(xs_final.columns.values, ['feiertag', 'ferientag'])

# %%
df = getDataframe(zaehlstelle='Arnulf', prefixes = ('rad2017', 'rad2018', 'rad2019'))
df['date'] = pd.to_datetime(df['datum'], format="%Y.%m.%d")
df = add_datepart(df, 'datum')
add_date_feature(df, 'feiertag', feiertage_df['date'])
add_date_feature(df, 'ferientag', ferientage_df['date'])
df = df.drop(['richtung_1', 'richtung_2'], axis=1)
# df = df[list(usedColumns) + [dep_var]] reduce columns after train valid set is created because year is used
df
# Out:
#    uhrzeit_start uhrzeit_ende  datumWeek zaehlstelle  gesamt  min-temp  \
# 0       00:00:00        23.59         52      Arnulf     135      -6.1
# 1       00:00:00        23.59          1      Arnulf     400      -5.4
# 2       00:00:00        23.59          1      Arnulf     262      -2.1
# 3       00:00:00        23.59          1      Arnulf     207      -0.9
# 4       00:00:00        23.59          1      Arnulf     224      -7.1
# ..           ...          ...        ...         ...     ...       ...
# 26         00:00        23.59         52      Arnulf     342       1.7
# 27         00:00        23.59         52      Arnulf     374      -2.1
# 28         00:00        23.59         52      Arnulf     285      -4.8
# 29         00:00        23.59          1      Arnulf     602      -4.4
# 30         00:00        23.59          1      Arnulf     363      -0.5
#
#     max-temp  niederschlag  bewoelkung  sonnenstunden  ... datumDayofyear  \
# 0        2.6           0.0          36            5.9  ...              1
# 1        0.8           3.2          69            0.3  ...              2
# 2        0.6           0.0          85            3.6  ...              3
# 3        1.3           2.2          94            0.0  ...              4
# 4       -0.2           0.0          88            0.0  ...              5
# ..       ...           ...         ...            ...  ...            ...
# 26       4.9           4.9          98            0.0  ...            361
# 27       2.0           0.0          69            3.2  ...            362
# 28       2.5           0.0          26            7.9  ...            363
# 29       6.0           0.0           9            8.0  ...            364
# 30       8.6           0.0          60            6.8  ...            365
#
#     datumIs_month_end  datumIs_month_start  datumIs_quarter_end  \
# 0               False                 True                False
# 1               False                False                False
# 2               False                False                False
# 3               False                False                False
# 4               False                False                False
# ..                ...                  ...                  ...
# 26              False                False                False
# 27              False                False                False
# 28              False                False                False
# 29              False                False                False
# 30               True                False                 True
#
#     datumIs_quarter_start  datumIs_year_end  datumIs_year_start  datumElapsed  \
# 0                    True             False                True    1483228800
# 1                   False             False               False    1483315200
# 2                   False             False               False    1483401600
# 3                   False             False               False    1483488000
# 4                   False             False               False    1483574400
# ..                    ...               ...                 ...           ...
# 26                  False             False               False    1577404800
# 27                  False             False               False    1577491200
# 28                  False             False               False    1577577600
# 29                  False             False               False    1577664000
# 30                  False              True               False    1577750400
#
#     feiertag  ferientag
# 0       True      False
# 1      False      False
# 2      False      False
# 3      False      False
# 4      False      False
# ..       ...        ...
# 26     False       True
# 27     False       True
# 28     False       True
# 29     False       True
# 30     False       True
#
# [1034 rows x 25 columns]

# %%
# Create Tabular Pandas
procs = [Categorify, FillMissing] # processings or transformations
cond = (df.datumYear<2019)
train_idx = np.where(cond)[0]
valid_idx = np.where(~cond)[0]
splits = (list(train_idx),list(valid_idx))

cont, cat = cont_cat_split(df, 1, dep_var=dep_var)
to = TabularPandas(df, procs, cat, cont, y_names=dep_var, splits=splits)

# %%
xs,y = to.train.xs, to.train.y
valid_xs, valid_y = to.valid.xs, to.valid.y

# %%
xs = xs[list(usedColumns)]
valid_xs = valid_xs[list(usedColumns)]

# %%
m = rf(xs,y)

# %%
m_rmse(m, valid_xs, valid_y)
# Out:
# 275.160738

# %% [markdown]
# 😳better then version without holidays: first run 273 vs 287 old

# %% [markdown]
# How important are the new features?

# %%
rf_feat_importance(m, xs)
# Out:
#               cols       imp
# 0         max-temp  0.443495
# 1   datumDayofweek  0.207359
# 3         min-temp  0.109623
# 2    sonnenstunden  0.106513
# 4   datumDayofyear  0.032325
# 5     niederschlag  0.028718
# 7        datumWeek  0.026704
# 6       bewoelkung  0.018904
# 10        feiertag  0.007568
# 8         datumDay  0.006836
# 11       ferientag  0.006509
# 9       datumMonth  0.005447

# %% [markdown]
# #### Take another look at the biggest errors

# %%
rf_pred = m.predict(valid_xs)

# %%
error = np.subtract(rf_pred, valid_y).abs()

# %%
pd.options.mode.chained_assignment = None # avoid SettingWithCopyError, is this a good idea?
df_errors = df.iloc[valid_idx]
df_errors['pred'] = rf_pred
df_errors['error'] = error
df_errors.columns
# Out:
# Index(['uhrzeit_start', 'uhrzeit_ende', 'datumWeek', 'zaehlstelle', 'gesamt',
#        'min-temp', 'max-temp', 'niederschlag', 'bewoelkung', 'sonnenstunden',
#        'date', 'datumYear', 'datumMonth', 'datumDay', 'datumDayofweek',
#        'datumDayofyear', 'datumIs_month_end', 'datumIs_month_start',
#        'datumIs_quarter_end', 'datumIs_quarter_start', 'datumIs_year_end',
#        'datumIs_year_start', 'datumElapsed', 'feiertag', 'ferientag', 'pred',
#        'error'],
#       dtype='object')

# %%
df_errors.sort_values(by = 'error', ascending=False)[['date', 'datumDayofweek', 'min-temp', 'feiertag', 'ferientag', 'error', 'gesamt', 'pred']][:10]
# Out:
#          date  datumDayofweek  min-temp  feiertag  ferientag        error  \
# 18 2019-04-19               4       5.5      True       True  1132.703424
# 29 2019-05-30               3       8.6      True      False  1031.064605
# 30 2019-05-31               4      11.7     False      False   908.664908
# 21 2019-04-22               0       6.5      True       True   874.534186
# 23 2019-05-24               4       6.3     False      False   754.729013
# 0  2019-05-01               2       4.7      True      False   750.253612
# 26 2019-05-27               0      11.2     False      False   729.105835
# 21 2019-10-22               1      10.5     False      False   683.254344
# 14 2019-08-15               3       9.8      True       True   674.154909
# 4  2019-12-05               3      -4.8     False      False   631.608982
#
#     gesamt         pred
# 18     785  1917.703424
# 29     593  1624.064605
# 30     751  1659.664908
# 21     843  1717.534186
# 23    1194  1948.729013
# 0     1061  1811.253612
# 26     817  1546.105835
# 21    1873  1189.745656
# 14     769  1443.154909
# 4     1381   749.391018

# %% [markdown]
# #### Plot biggest errors
#
# Can I see clusters when plotting the biggest errors?

# %%
top_errors = df_errors.sort_values(by = 'error', ascending=False)[:20]
plotResults(top_errors, top_errors)

# %% [markdown]
# There is a week in may in which some errors occur.

# %% [markdown]
# ### 5.3 NeuronalNet with new data

# %%
usedColumns[usedColumns!='datumDay']
# Out:
# array(['max-temp', 'datumDayofweek', 'sonnenstunden', 'min-temp',
#        'datumDayofyear', 'niederschlag', 'bewoelkung', 'datumWeek',
#        'datumMonth', 'feiertag', 'ferientag'], dtype=object)

# %%
# usedColumns = usedColumns[usedColumns!='datumDay'] #remove datumDay in future? it is the day in the month does it say sth dayInYear cannot say?

df_nn = getDataframe(zaehlstelle='Arnulf', prefixes = ('rad2017', 'rad2018', 'rad2019'))
df_nn['date'] = pd.to_datetime(df_nn['datum'], format="%Y.%m.%d")
df_nn = add_datepart(df_nn, 'datum')
add_date_feature(df_nn, 'feiertag', feiertage_df['date'])
add_date_feature(df_nn, 'ferientag', ferientage_df['date'])
df_nn = df_nn.drop(['richtung_1', 'richtung_2'], axis=1)
df_full = df_nn
df_nn = df_nn[list(usedColumns) + [dep_var]] #reduce columns after train valid set is created because year is used
df_nn
# Out:
#     max-temp  datumDayofweek  sonnenstunden  min-temp  datumDayofyear  \
# 0        2.6               6            5.9      -6.1               1
# 1        0.8               0            0.3      -5.4               2
# 2        0.6               1            3.6      -2.1               3
# 3        1.3               2            0.0      -0.9               4
# 4       -0.2               3            0.0      -7.1               5
# ..       ...             ...            ...       ...             ...
# 26       4.9               4            0.0       1.7             361
# 27       2.0               5            3.2      -2.1             362
# 28       2.5               6            7.9      -4.8             363
# 29       6.0               0            8.0      -4.4             364
# 30       8.6               1            6.8      -0.5             365
#
#     niederschlag  bewoelkung  datumWeek  datumDay  datumMonth  feiertag  \
# 0            0.0          36         52         1           1      True
# 1            3.2          69          1         2           1     False
# 2            0.0          85          1         3           1     False
# 3            2.2          94          1         4           1     False
# 4            0.0          88          1         5           1     False
# ..           ...         ...        ...       ...         ...       ...
# 26           4.9          98         52        27          12     False
# 27           0.0          69         52        28          12     False
# 28           0.0          26         52        29          12     False
# 29           0.0           9          1        30          12     False
# 30           0.0          60          1        31          12     False
#
#     ferientag  gesamt
# 0       False     135
# 1       False     400
# 2       False     262
# 3       False     207
# 4       False     224
# ..        ...     ...
# 26       True     342
# 27       True     374
# 28       True     285
# 29       True     602
# 30       True     363
#
# [1034 rows x 13 columns]

# %% [markdown]
# I use the default value for `max_card=20` in comparison to the first run. Which leads to better continuos and categorical splits in my opinion. e.g. bewoelkung is now continous. I also tested it once with a dayOfYear as category but it let to worse performance.

# %%
cont_nn, cat_nn = cont_cat_split(df_nn, dep_var=dep_var)
#cont_nn.append('bewoelkung')
#cat_nn.remove('bewoelkung')

# %%
cont_nn, cat_nn
# Out:
# (['max-temp',
#   'sonnenstunden',
#   'min-temp',
#   'datumDayofyear',
#   'niederschlag',
#   'bewoelkung',
#   'datumDay'],
#  ['datumDayofweek', 'datumWeek', 'datumMonth', 'feiertag', 'ferientag'])

# %%
df_nn[cat_nn].nunique()
# Out:
# datumDayofweek     7
# datumWeek         52
# datumMonth        12
# feiertag           2
# ferientag          2
# dtype: int64

# %%
df_nn=df_nn.astype('float')
procs_nn = [Categorify, FillMissing, Normalize]
to_nn = TabularPandas(df_nn, procs_nn, cat_nn, cont_nn, splits=splits, y_names=dep_var)
dls = to_nn.dataloaders()

# %%
learn = tabular_learner(dls, n_out=1, loss_func=F.mse_loss) # removed all config params and just use default, model optimization is for another time

# %%
learn.fit_one_cycle(20, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1799191.625000</td>
#       <td>1432403.625000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1800613.875000</td>
#       <td>1429459.250000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1781488.000000</td>
#       <td>1384360.375000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1638559.875000</td>
#       <td>918231.687500</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1264602.375000</td>
#       <td>160868.390625</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>960281.187500</td>
#       <td>115074.460938</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>742565.687500</td>
#       <td>117674.804688</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>588246.125000</td>
#       <td>108339.812500</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>464676.687500</td>
#       <td>79417.773438</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>371596.375000</td>
#       <td>71945.789062</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>300859.375000</td>
#       <td>84787.046875</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>247186.546875</td>
#       <td>66144.156250</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>204744.906250</td>
#       <td>74213.398438</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>171803.343750</td>
#       <td>69482.640625</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>148610.296875</td>
#       <td>78572.851562</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>129241.562500</td>
#       <td>71682.250000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>111617.007812</td>
#       <td>67417.234375</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>98853.625000</td>
#       <td>65321.953125</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>88185.195312</td>
#       <td>65257.750000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>81710.507812</td>
#       <td>64515.050781</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds,targs = learn.get_preds()
r_mse(preds,targs)
# Out:
# 253.998131

# %% [markdown]
# Also better than previous model: 253 vs 287

# %% [markdown]
# ### Check top errors

# %%
df_err_nn = df_full.iloc[valid_idx]

# %%
errors = pd.DataFrame(torch.sub(preds, targs).abs().numpy())

# %%
pd.options.mode.chained_assignment = None
df_err_nn['error'] = errors.to_numpy()
df_err_nn['pred'] = preds.numpy()

# %%
df_err_nn.columns
# Out:
# Index(['uhrzeit_start', 'uhrzeit_ende', 'datumWeek', 'zaehlstelle', 'gesamt',
#        'min-temp', 'max-temp', 'niederschlag', 'bewoelkung', 'sonnenstunden',
#        'date', 'datumYear', 'datumMonth', 'datumDay', 'datumDayofweek',
#        'datumDayofyear', 'datumIs_month_end', 'datumIs_month_start',
#        'datumIs_quarter_end', 'datumIs_quarter_start', 'datumIs_year_end',
#        'datumIs_year_start', 'datumElapsed', 'feiertag', 'ferientag', 'error',
#        'pred'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', 500)
df_err_nn.sort_values(by = 'error', ascending=False)[['date', 'datumDayofweek', 'min-temp', 'feiertag', 'ferientag', 'error', 'gesamt', 'pred']]
# Out:
#          date  datumDayofweek  min-temp  feiertag  ferientag       error  \
# 22 2019-05-23               3       7.6     False      False  807.143311
# 23 2019-05-24               4       6.3     False      False  783.294678
# 30 2019-05-31               4      11.7     False      False  746.057861
# 28 2019-05-29               2       9.4     False      False  727.062500
# 27 2019-05-28               1       9.5     False      False  713.334473
# 21 2019-05-22               2       8.8     False      False  700.128052
# 20 2019-05-21               1      10.5     False      False  689.682800
# 9     1927  1878.115112
# 18    1243  1195.110840
# 7      297   249.670364
# 1      385   338.270172
# 25    1064  1109.231689
# 2     1021   976.265015
# 9      204   247.567825
# 10    1267  1224.251709
# 0      386   428.623413
# 28     285   242.731445
# 7     1191  1148.776489
# 14     517   558.314697
# 19    1015   974.443054
# 27     561   521.216431
# 29     602   562.667358
# 8      570   608.944092
# 16    1952  1990.704224
# 29     755   790.866943
# 4     1218  1182.871948
# 18     280   245.126038
# 26     215   245.195435
# 0      152   180.262222
# 27     806   778.434448
# 4      786   813.286804
# 0     1061  1088.156860
# 29     920   892.994751
# 13    1938  1964.975952
# 28     905   931.847534
# 17     928   902.483154
# 26    1000   975.473999
# 14    2081  2056.713135
# 7     1415  1391.172729
# 4      514   537.355103
# 15    1679  1656.281616
# 1      256   234.836990
# 15    1686  1706.324463
# 0     1592  1610.396851
# 15    1872  1889.604736
# 30     844   861.527039
# 25     213   196.005402
# 14     769   785.835938
# 13    1244  1228.313721
# 6      961   946.840698
# 25    1095  1080.969971
# 17    1944  1931.779785
# 14    1216  1208.082397
# 24    1152  1144.561401
# 27    1032  1026.904175
# 21     678   673.180420
# 16     372   375.833130
# 0     1001  1004.757507
# 9     1238  1241.671387
# 20    1165  1168.362793
# 9     1454  1450.941162
# 15    1232  1234.918213
# 26    2056  2053.376465
# 27     902   904.560181
# 28    1203  1203.244385

# %%
pd.reset_option('display.max_rows')

# %%
top_errors = df_err_nn.sort_values(by = 'error', ascending=False)[:20]
plotResults(top_errors, top_errors)

# %% [markdown]
# Also here are a few errors at end of may.

# %% [markdown]
# ## 5. Conclusion <a name="conclusion"></a>

# %%
* base model for model development
* randomforest great to understand a dataset and improve columns to use, also for a neuronal net
* learned a lot about features and data management
* just by improving data got better results
* learned a few facts about biking

Possible next Steps:
    
* is this data helpful for real world usecase e.g. a traffic planer? compare to canadian paper
* I only tried for one counting station, use all of them
* use different data for weather information? is 
* Imprve models I only used the default supplied

# %% [markdown]
# ### Are these models helpful?
#
# I tried two approaches RandomForest and a Neuronal Net and both seem to work in general, but I still have no real feeling if the models are helpful and what the RSME (RootMeanSquaredError) means for the quality of my model in general. Are those good models that would be helpful?
#
# Should I use another metric?
# Are there other metrics besided RSME (RootSquareMeanError) that would make it easier for me to grasp the performance of my model? Should I maybe use a relative metric? e.g. a percentage Metric? or would MeanAbsoluteError help me?
# The OOB score is relative from 0 (bad) to 1 (good). It was arround 0.88. Does that mean it is an okay model?
#
# Or does the real value of the predictions only gets visible when I would have a real use case in which they are used? e.g. is an value 100 below the real value helpful for traffic planners?
#
# ### RandomForest
#
# * Results change on every rerun. Therfore: How comparable are the results with the different changes then? Should I fix a seed for the RandomForest, is this possible?
# * What does it mean if the predictions get worse with more trees?
#
#
# ### Future Steps
#
# * I really like the waterfall chart for the RandomForest which shows which influence different features have. Is there something similiar for a neural net? e.g. like the visualisation of CNN Layers for image classification
# * Add bavarian holidays to the data
# * Use not only one counting station but the total of all six
# * Use datasets where weekdays and weekends are seperated. Could I train a "Should I bike or take the bus?"-Model on this?
